# %%
import pandas as pd
from matplotlib import pyplot as plt

# %% [markdown]
# ## A grouped bar chart displays two or more sets of data side by side for each category. This format allows for easy comparison of different groups within the same category, making it ideal for analyzing multiple dimensions of data.
# ## As a business analyst, I could use a grouped bar chart to compare quarterly revenue for multiple product lines across several regions. Each group of bars would represent a product line, with different colors for each region. This visualization would provide a clear view of how each product line performs in different markets, highlighting regional strengths and weaknesses.
# ## By using a grouped bar chart, I can effectively communicate insights about product performance across regions, guiding strategic business decisions.

# %%
cces = pd.read_csv('cces_example_data.csv')
cces.head()
# Out:
#    pew_religimp  pew_churatd  sex  educ  nonwhite  age  faminc_new  pid3  \
# 0             2            6    2     2         1   56           6     1
# 1             2            4    2     5         1   53          13     1
# 2             1            2    1     2         1   69          10     2
# 3             2            3    1     6         1   76          97     1
# 4             4            5    2     6         1   83           4     1
#
#    ideo5  QueerPhobia  ...  InterGBiasParty  InterGBiasCand  InterGBiasSup  \
# 0      1     1.000000  ...              -99             -99            -96
# 1      2     3.000000  ...             -100            -100           -100
# 2      5     4.333333  ...               99              99             96
# 3      3     1.000000  ...              -86             -91            -89
# 4      2     1.000000  ...              -80             -88            -87
#
# ...

# %%
cces.describe()
# Out:
#        pew_religimp  pew_churatd         sex        educ    nonwhite  \
# count    659.000000   659.000000  659.000000  659.000000  659.000000
# mean       2.342944     4.294385    1.559939    3.813354    1.254932
# std        1.192998     1.725409    0.496771    1.471121    0.436154
# min        1.000000     1.000000    1.000000    1.000000    1.000000
# 25%        1.000000     3.000000    1.000000    2.000000    1.000000
# 50%        2.000000     5.000000    2.000000    4.000000    1.000000
# 75%        4.000000     6.000000    2.000000    5.000000    2.000000
# max        4.000000     7.000000    2.000000    6.000000    2.000000
#
#               age  faminc_new        pid3       ideo5  QueerPhobia  ...  \
# count  659.000000  659.000000  659.000000  659.000000   659.000000  ...
# mean    52.180577   15.908953    1.977238    3.083460     2.600910  ...
# std     16.842264   27.724506    0.860002    1.282575     1.163468  ...
# ...

# %%
fig, (ax1, ax2) = plt.subplots(1, 2 )
ax1.set_title('Age Histogram')
ax2.set_title('Political Identity')
plt.show()

# %%
fig, ax = plt.subplots()
cces['Evaluation'].value_counts().plot(kind='bar', ax=ax)
ax.set_title('Evaluation Bar Plot')
ax.set_xlabel('Evaluation')
ax.set_ylabel('count')
plt.show()

# %%
fig, ax = plt.subplots()
ax.scatter(cces['ConMediaUse'], cces['ImmiPhobia'],marker="D")
ax.set_title('Scatter Plot of ConMediaUse vs ImmiPhobia')
ax.set_xlabel('ConMediaUse')
ax.set_ylabel('ImmiPhobia')
plt.show()

# %% [markdown]
# ## To improve the scatterplot of ConMediaUse vs ImmiPhobia, several techniques can enhance clarity and readability. One key improvement is addressing overlapping points by using transparency or jittering, which helps reveal data density in congested areas (partial-transparency-and-jittering, Page no 18.1). Adding a trend line, such as a regression line, can provide insights into the overall relationship between the variables (directory-of-visualizations, Page no 5.4). Customizing the point size, shape, or color to reflect additional variables like age or education further enhances the visualization’s depth (directory-of-visualizations, Page no 5). Lastly, applying a logarithmic scale for better axis representation and improving axis labels will make the plot more informative and accessible (what-is-a-story, Page no 29.1 ).
